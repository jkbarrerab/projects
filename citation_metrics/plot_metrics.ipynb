# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cites = pd.read_csv('cites_table.csv')
df_cites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               12 non-null     int64
#  1    cite_year         12 non-null     int64
#  2    cites_cumulative  12 non-null     int64
# dtypes: int64(3)
# memory usage: 416.0 bytes

# %%
plt.plot(df_cites['year'], df_cites[' cites_cumulative'])
plt.xlabel('year')
plt.ylabel('cumulative cites')
# Out:
# Text(0, 0.5, 'cumulative cites')
